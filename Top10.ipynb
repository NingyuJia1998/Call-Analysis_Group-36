# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
#read the data
data=pd.read_csv('311_Service_Requests_2020.csv',encoding='utf-8')
data.head()
# Out:
# /Users/melodyma/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (20,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45285347  01/01/2020 12:00:00 AM  01/10/2020 12:00:01 AM  DOHMH
# 1    45285651  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 2    45285821  01/01/2020 12:00:00 AM  01/02/2020 09:50:09 AM  DOHMH
# 3    45287907  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 4    45288240  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
#
#                                Agency Name  Complaint Type Descriptor  \
# 0  Department of Health and Mental Hygiene  Food Poisoning  3 or More
# 1  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 2  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# ...

# %%
#check whether all entries happen in 2020
data['Created Date']=pd.to_datetime(data['Created Date'],format="%m/%d/%Y %H:%M:%S %p")
data['Created Date'].dt.year.value_counts()
# Out:
# 2020    2587316
# Name: Created Date, dtype: int64

# %%
#use zip code as 10025
data_10025=data.loc[(data['Incident Zip']==10025.0)]
data_10025 #20978*41
# Out:
#          Unique Key        Created Date             Closed Date Agency  \
# 11         45278238 2020-01-01 12:01:46  01/01/2020 05:37:46 AM   NYPD
# 141        45278928 2020-01-01 12:36:42  01/01/2020 01:19:30 AM   NYPD
# 463        45282069 2020-01-01 01:37:02  01/01/2020 01:55:21 AM   NYPD
# 979        45286989 2020-01-01 03:33:15  02/21/2020 08:45:41 AM    TLC
# 1166       45287132 2020-01-01 04:33:27  01/03/2020 05:46:11 AM    HPD
# ...             ...                 ...                     ...    ...
# 2586233    48532983 2020-12-30 08:11:19  01/01/2021 06:35:12 PM    HPD
# 2586442    48531180 2020-12-30 08:55:03  12/30/2020 09:48:13 PM   NYPD
# 2586758    48535864 2020-12-30 10:05:50  01/12/2021 11:58:43 AM  DOHMH
# 2586833    48532767 2020-12-30 10:18:40  12/30/2020 10:28:10 PM   NYPD
# 2586908    48533796 2020-12-30 10:35:52  12/30/2020 10:52:44 PM   NYPD
#
#                                                Agency Name  \
# ...

# %%
#pick the top 10 causes of 311 calls
top10=data_10025['Complaint Type'].value_counts().head(10)
top10
# Out:
# Noise - Residential            2952
# Noise - Street/Sidewalk        2128
# HEAT/HOT WATER                 1885
# Noise                          1131
# Illegal Parking                 792
# Noise - Vehicle                 787
# Non-Emergency Police Matter     773
# Rodent                          691
# Illegal Fireworks               672
# UNSANITARY CONDITION            565
# Name: Complaint Type, dtype: int64
